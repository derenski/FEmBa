# %%
library(dplyr)
library(MASS)
library(ggplot2)

# %%
XDistribution <- rbeta(100000, shape1=1, shape2=1)

# %%
muGivenXDistribution <- rgamma(100000, shape=1, scale=3)

# %%
XGivenMuDistribution <- rnorm(10000, mean=0, sd=4)

# %%
gMu <- function(mu, muGivenX, ...){
    
    vals <- muGivenX(mu, ...)
    
    return(mean(vals))
    
}

# %%
priorDensVals <- sapply(seq(0.1, 10, .1), FUN = function(x) gMu(x, muGivenX=dgamma, shape=XDistribution, scale=3))

# %%
plot(priorDensVals ~ seq(0.1, 10, .1), type='l')
# Out:
# plot without title
